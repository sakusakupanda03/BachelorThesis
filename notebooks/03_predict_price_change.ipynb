# %% [markdown]
# <a href="https://colab.research.google.com/github/sakusakupanda03/BachelorThesis/blob/main/notebooks/03_predict_price_change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import pacf, adfuller
from statsmodels.stats.diagnostic import acorr_ljungbox
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.metrics import f1_score

path = "../data"
path = "/content/drive/MyDrive/sotsuron/data"

# %% [markdown]
# # Create functions to experiment

# %%
def prepare_datasets():
    btc = pd.read_pickle(path + "/03_primary/btc.pickle")
    eth = pd.read_pickle(path + "/03_primary/eth.pickle")

    btc["price_change_binary_shifted"] = btc["price_change_binary"].shift(-1)
    eth["price_change_binary_shifted"] = eth["price_change_binary"].shift(-1)
    btc = btc.dropna()
    eth = eth.dropna()

    btc_X = btc[['market-cap', 'price_change', 'avg-block-size', 'avg-confirmation-time',
                'hash-rate', 'difficulty', 'miners-revenue', 'transaction-fees',
                'fees-usd-per-transaction', 'n-unique-addresses', 'n-transactions', 'price_change_binary']]
    btc_y = btc['price_change_binary_shifted']
    print("Num of columns on BTC independent variables:", len(btc_X.columns))

    eth_X = eth[['export-MarketCap', 'price_change', 'export-BlockSize', 'export-BlockTime', 
                'export-NetworkHash', 'export-BlockDifficulty', 'export-GasUsed', 'export-TransactionFee',
                'export-AverageDailyTransactionFee', 'export-DailyActiveEthAddress', 'export-verified-contracts', 'price_change_binary']]
    eth_y = eth['price_change_binary_shifted']
    print("Num of columns on ETH independent variables:", len(eth_X.columns))

    return btc_X, btc_y, eth_X, eth_y

# %%
def split_train_test_ts(X, y, train_start_month, train_end_month, test_month):
    X_train = X[train_start_month: train_end_month]
    y_train = y[train_start_month: train_end_month]
    X_test = X[test_month: test_month]
    y_test = y[test_month: test_month]

    return X_train, y_train, X_test, y_test

# %%
def build_lr(X_train, y_train, X_test, y_test, best_params, model):
    StdSc_train = StandardScaler()
    X_train = pd.DataFrame(StdSc_train.fit_transform(X_train), columns = X_train.columns)
    X_test = pd.DataFrame(StdSc_train.transform(X_test), columns = X_test.columns)

    m = model(**best_params, random_state=202209)
    m.fit(X_train, y_train)
    y_pred = m.predict(X_test)
    test_score = f1_score(y_test, y_pred)

    print("Mean of actual:       ", np.mean(y_test))
    print("Mean of predictions:  ", np.mean(y_pred))
    print("Test score:           ", test_score)

    return test_score


def build_rf(X_train, y_train, X_test, y_test, best_params, model):
    m = model(**best_params, random_state=202209)
    m.fit(X_train, y_train)
    y_pred = m.predict(X_test)
    test_score = f1_score(y_test, y_pred)

    print("Mean of actual:       ", np.mean(y_test))
    print("Mean of predictions:  ", np.mean(y_pred))
    print("Test score:           ", test_score)

    m_fi = model(**best_params, random_state=202209)
    m_fi.fit(X_test, y_test)
    fi = m_fi.feature_importances_
    series_fi = pd.Series(fi, index=X_train.columns)

    return test_score, series_fi

# %%
def tune_hyperparams(X_train, y_train, model):
    m = model()
    if model == RandomForestClassifier:
        cv_params = {
        'n_estimators': list(range(300, 800+1)),
        'max_depth' : list(range(3, 8+1))
        }
    elif model == LogisticRegression:
        cv_params = {"solver": ['newton-cg', 'lbfgs', 'liblinear'],
            "penalty": ['l2'],
            "C": [100, 10, 1.0, 0.1, 0.01],
            "max_iter": [1500]
        }
    else:
        None

    cv = RandomizedSearchCV(estimator=m, param_distributions=cv_params, cv = 5, n_iter=10, scoring="f1_weighted", random_state=202209)
    cv.fit(X_train, y_train)
    best_params = cv.best_params_
    train_score = cv.best_score_
    print("Best params: ", best_params)
    print("Train score: ", train_score)

    return best_params, train_score

## https://machinelearningmastery.com/hyperparameters-for-classification-machine-learning-algorithms/

# %%
def iterate_predictions(num_train_months, X, y, model = RandomForestClassifier):
    month_list = ["2019-08","2019-09","2019-10","2019-11",
                "2019-12","2020-01","2020-02","2020-03",
                "2020-04","2020-05","2020-06","2020-07",
                "2020-08","2020-09","2020-10","2020-11",
                "2020-12","2021-01","2021-02","2021-03",
                "2021-04","2021-05","2021-06","2021-07",
                "2021-08","2021-09","2021-10","2021-11",
                "2021-12","2022-01","2022-02","2022-03",
                "2022-04","2022-05","2022-06","2022-07",
                "2022-08"]
    windows_list = [{month_list[m + num_train_months]: [month_list[m], month_list[m + num_train_months - 1]]} for m in range(len(month_list)-num_train_months)]

    test_months = []
    pacf_scores= []
    train_scores = []
    test_scores = []
    list_fi = []
    for l in windows_list:
        train_start_month = list(l.values())[0][0]
        train_end_month = list(l.values())[0][1]
        test_month = list(l.keys())[0]
        print(test_month)
        test_months.append(test_month)

        pacf_score = pacf(y[test_month: test_month], nlags=1)[1]
        pacf_scores.append(pacf_score)

        X_train, y_train, X_test, y_test = split_train_test_ts(X, y, train_start_month, train_end_month, test_month)
        best_params, train_score = tune_hyperparams(X_train, y_train, model = model)

        if model == LogisticRegression:
            test_score = build_lr(X_train, y_train, X_test, y_test, best_params = best_params, model = model)
            list_fi = [0]*len(windows_list)
        if model == RandomForestClassifier:
            test_score, series_fi = build_rf(X_train, y_train, X_test, y_test, best_params = best_params, model = model)
            list_fi.append(series_fi)

        train_scores.append(train_score)
        test_scores.append(test_score)

    return test_months, pacf_scores, train_scores, test_scores, list_fi

# %%
def iterate_predictions_btc_eth(num_train_months, model = RandomForestClassifier):
    print("Num train months: ", num_train_months)
    print("Model: ", model)
    print("BTC")
    btc_test_months, btc_pacf_scores, btc_train_scores, btc_test_scores, btc_list_fi = iterate_predictions(num_train_months = num_train_months, X = btc_X, y = btc_y, model = model) 
    print("ETH")
    eth_test_months, eth_pacf_scores, eth_train_scores, eth_test_scores, eth_list_fi = iterate_predictions(num_train_months = num_train_months, X = eth_X, y = eth_y, model = model)

    res_df = pd.DataFrame({"BTC PACF Scores": btc_pacf_scores, "ETH PACF Scores": eth_pacf_scores, "BTC Train Scores": btc_train_scores, "ETH Train Scores": eth_train_scores, "BTC Test Scores": btc_test_scores, "ETH Test Scores": eth_test_scores, "BTC Features Importance": btc_list_fi, "ETH Features Importance": eth_list_fi}, index=btc_test_months).T
    if model == LogisticRegression:
        res_df.to_pickle(path + "/04_reporting" + f"/num_train_months_{num_train_months}_lr.pickle")
    if model == RandomForestClassifier:
        res_df.to_pickle(path + "/04_reporting" + f"/num_train_months_{num_train_months}_rf.pickle")


    return btc_test_months, btc_pacf_scores, btc_train_scores, btc_test_scores, eth_test_months, eth_pacf_scores, eth_train_scores, eth_test_scores

# %% [markdown]
# # Load the datasets

# %%
btc_X, btc_y, eth_X, eth_y = prepare_datasets()
# Out:
# Num of columns on BTC independent variables: 12
# Num of columns on ETH independent variables: 12

# %% [markdown]
# # Predict the price change binary

# %%
for i in [4, 9]:
    for j in [LogisticRegression, RandomForestClassifier]:
        iterate_predictions_btc_eth(num_train_months = i, model = j)
# Out:
# Num train months:  4
# Model:  <class 'sklearn.linear_model._logistic.LogisticRegression'>
# BTC
# 2019-12
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5483904051130942
# Mean of actual:        0.3870967741935484
# Mean of predictions:   0.3870967741935484
# Test score:            0.3333333333333333
# 2020-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5701136363636363
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.3870967741935484
# Test score:            0.6206896551724139
# 2020-02
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6127042387814846
# Mean of actual:        0.5172413793103449
# Mean of predictions:   0.27586206896551724
# Test score:            0.3478260869565218
# 2020-03
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5661225634269113
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.41935483870967744
# Test score:            0.7333333333333334
# 2020-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5785505774900551
# Mean of actual:        0.6
# Mean of predictions:   0.4666666666666667
# Test score:            0.6250000000000001
# 2020-05
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6099853406630018
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5806451612903226
# Test score:            0.6111111111111112
# 2020-06
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5005921062516557
# Mean of actual:        0.5
# Mean of predictions:   0.7333333333333333
# Test score:            0.5405405405405405
# 2020-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5725578099838969
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6774193548387096
# Test score:            0.8
# 2020-08
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.6137492638080874
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.5806451612903226
# Test score:            0.7428571428571428
# 2020-09
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.635559706959707
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.5333333333333333
# Test score:            0.7272727272727272
# 2020-10
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6787726765987635
# Mean of actual:        0.7096774193548387
# Mean of predictions:   0.4838709677419355
# Test score:            0.5405405405405405
# 2020-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5881964136278011
# Mean of actual:        0.6
# Mean of predictions:   0.6
# Test score:            0.6666666666666666
# 2020-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5452599255068028
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.7741935483870968
# Test score:            0.7555555555555556
# 2021-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5390569370990423
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.5806451612903226
# Test score:            0.823529411764706
# 2021-02
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5696401206636501
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.7857142857142857
# Test score:            0.8108108108108109
# 2021-03
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6343187923439737
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.5806451612903226
# Test score:            0.6842105263157895
# 2021-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.661481513426485
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5666666666666667
# Test score:            0.5806451612903226
# 2021-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6380797639853146
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.3870967741935484
# Test score:            0.6923076923076924
# 2021-06
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6445107997379756
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.4666666666666667
# Test score:            0.6428571428571429
# 2021-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6447472527472528
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.5483870967741935
# Test score:            0.6111111111111113
# 2021-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5663588842719277
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.4838709677419355
# Test score:            0.6
# 2021-09
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5854041867954911
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.5
# Test score:            0.6451612903225806
# 2021-10
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6849301912480323
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5806451612903226
# Test score:            0.8333333333333334
# 2021-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6478521427117129
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.6
# Test score:            0.75
# 2021-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.7284347826086957
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.45161290322580644
# Test score:            0.5517241379310344
# 2022-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6571904020648596
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.6129032258064516
# Test score:            0.5882352941176471
# 2022-02
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 0.1}
# Train score:  0.58270568611798
# Mean of actual:        0.5
# Mean of predictions:   0.42857142857142855
# Test score:            0.5384615384615384
# 2022-03
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5132602253991
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.4838709677419355
# Test score:            0.5
# 2022-04
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.457950358819924
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5
# Test score:            0.4827586206896552
# 2022-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 0.01}
# Train score:  0.5087866336561989
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.41935483870967744
# Test score:            0.4000000000000001
# 2022-06
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5454178850424413
# Mean of actual:        0.4
# Mean of predictions:   0.5333333333333333
# Test score:            0.6428571428571429
# 2022-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5618621925578448
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.5806451612903226
# Test score:            0.5
# 2022-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.47978511283735836
# Mean of actual:        0.4
# Mean of predictions:   0.5
# Test score:            0.6666666666666665
# ETH
# 2019-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5399139094234184
# Mean of actual:        0.41935483870967744
# Mean of predictions:   0.3870967741935484
# Test score:            0.4
# 2020-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5027629215368691
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.3225806451612903
# Test score:            0.38461538461538464
# 2020-02
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6086595950547101
# Mean of actual:        0.5862068965517241
# Mean of predictions:   0.41379310344827586
# Test score:            0.41379310344827586
# 2020-03
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5311287746070354
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.4838709677419355
# Test score:            0.5161290322580646
# 2020-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5250434782608695
# Mean of actual:        0.6
# Mean of predictions:   0.43333333333333335
# Test score:            0.45161290322580644
# 2020-05
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.570050462962963
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5806451612903226
# Test score:            0.4848484848484848
# 2020-06
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5132469581723563
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.6
# Test score:            0.5161290322580646
# 2020-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5950955099650752
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.41935483870967744
# Test score:            0.45161290322580644
# 2020-08
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5057740239673796
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.45161290322580644
# Test score:            0.5
# 2020-09
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5380434576362612
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6
# Test score:            0.6857142857142857
# 2020-10
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6031280788177341
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.6774193548387096
# Test score:            0.5641025641025642
# 2020-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5431024510318669
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6333333333333333
# Test score:            0.5555555555555555
# 2020-12
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.560251036721625
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.7741935483870968
# Test score:            0.7727272727272727
# 2021-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4647366562997493
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.5806451612903226
# Test score:            0.6666666666666666
# 2021-02
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4906886446886446
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.75
# Test score:            0.5555555555555556
# 2021-03
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 0.01}
# Train score:  0.46039136302294204
# Mean of actual:        0.5483870967741935
# Mean of predictions:   1.0
# Test score:            0.7083333333333333
# 2021-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5047118011823895
# Mean of actual:        0.6666666666666666
# Mean of predictions:   0.8333333333333334
# Test score:            0.6666666666666665
# 2021-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.520646986312621
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.7419354838709677
# Test score:            0.6315789473684211
# 2021-06
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5926587301587302
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.6333333333333333
# Test score:            0.5142857142857142
# 2021-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.46057958761847145
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.5806451612903226
# Test score:            0.4864864864864865
# 2021-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.41898824786324795
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.7419354838709677
# Test score:            0.6666666666666666
# 2021-09
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.514418042447644
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.6333333333333333
# Test score:            0.5454545454545454
# 2021-10
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6137412346835449
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.7096774193548387
# Test score:            0.7499999999999999
# 2021-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5350375289900906
# Mean of actual:        0.5
# Mean of predictions:   0.6666666666666666
# Test score:            0.7428571428571429
# 2021-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5759501560168228
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.7096774193548387
# Test score:            0.6111111111111112
# 2022-01
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 0.1}
# Train score:  0.5816771792465304
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.5806451612903226
# Test score:            0.5294117647058824
# 2022-02
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.582849964849965
# Mean of actual:        0.5
# Mean of predictions:   0.5714285714285714
# Test score:            0.39999999999999997
# 2022-03
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5627076627076628
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.4838709677419355
# Test score:            0.47058823529411764
# 2022-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4936941952304271
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.5666666666666667
# Test score:            0.4666666666666667
# 2022-05
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.4900506739637175
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.6129032258064516
# Test score:            0.48484848484848486
# 2022-06
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5296333103289624
# Mean of actual:        0.3333333333333333
# Mean of predictions:   0.43333333333333335
# Test score:            0.4347826086956522
# 2022-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.46410164341388205
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.25806451612903225
# Test score:            0.24
# 2022-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5240238303232617
# Mean of actual:        0.6
# Mean of predictions:   0.3
# Test score:            0.2222222222222222
# Num train months:  4
# Model:  <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# BTC
# 2019-12
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5939360442727583
# Mean of actual:        0.3870967741935484
# Mean of predictions:   0.25806451612903225
# Test score:            0.2
# 2020-01
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.508985782762111
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.22580645161290322
# Test score:            0.5833333333333334
# 2020-02
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5774084846776735
# Mean of actual:        0.5172413793103449
# Mean of predictions:   0.3793103448275862
# Test score:            0.4615384615384615
# 2020-03
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5274000460087416
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.6451612903225806
# Test score:            0.5945945945945946
# 2020-04
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5054960884526102
# Mean of actual:        0.6
# Mean of predictions:   0.43333333333333335
# Test score:            0.45161290322580644
# 2020-05
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5306808529863558
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.6129032258064516
# Test score:            0.6486486486486486
# 2020-06
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.5278149204492883
# Mean of actual:        0.5
# Mean of predictions:   0.6666666666666666
# Test score:            0.5142857142857143
# 2020-07
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.479944842270107
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6451612903225806
# Test score:            0.6153846153846154
# 2020-08
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.6310234872258587
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.8387096774193549
# Test score:            0.744186046511628
# 2020-09
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5663178581013726
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.5333333333333333
# Test score:            0.6666666666666667
# 2020-10
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.6317539588212613
# Mean of actual:        0.7096774193548387
# Mean of predictions:   0.4838709677419355
# Test score:            0.5945945945945945
# 2020-11
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.6134567261854548
# Mean of actual:        0.6
# Mean of predictions:   0.8
# Test score:            0.6666666666666666
# 2020-12
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5130260854341737
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.8387096774193549
# Test score:            0.7234042553191489
# 2021-01
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5853023601785212
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.9032258064516129
# Test score:            0.6818181818181818
# 2021-02
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5068864468864469
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.7857142857142857
# Test score:            0.7027027027027029
# 2021-03
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5401117256019217
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.7741935483870968
# Test score:            0.7272727272727272
# 2021-04
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5462793630310234
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.7333333333333333
# Test score:            0.6666666666666665
# 2021-05
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5244413831123875
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.45161290322580644
# Test score:            0.2857142857142857
# 2021-06
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5147485190990144
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.3333333333333333
# Test score:            0.5833333333333334
# 2021-07
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.5134026433336779
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.45161290322580644
# Test score:            0.48484848484848486
# 2021-08
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.4743470732166385
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5806451612903226
# Test score:            0.4848484848484848
# 2021-09
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.46013693945568007
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.4666666666666667
# Test score:            0.6000000000000001
# 2021-10
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5273703499565567
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5483870967741935
# Test score:            0.7428571428571428
# 2021-11
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5893182340673853
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.7
# Test score:            0.5714285714285714
# 2021-12
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5770002353320695
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.6451612903225806
# Test score:            0.5714285714285715
# 2022-01
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5611793157525028
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.4838709677419355
# Test score:            0.5333333333333333
# 2022-02
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.5315526505752972
# Mean of actual:        0.5
# Mean of predictions:   0.42857142857142855
# Test score:            0.6153846153846153
# 2022-03
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.5145540443695298
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.5483870967741935
# Test score:            0.47058823529411764
# 2022-04
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.49269648869648874
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5333333333333333
# Test score:            0.6666666666666666
# 2022-05
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5809579020013802
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.6129032258064516
# Test score:            0.5555555555555555
# 2022-06
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5576176673567977
# Mean of actual:        0.4
# Mean of predictions:   0.6666666666666666
# Test score:            0.625
# 2022-07
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5280754017485652
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.4838709677419355
# Test score:            0.4137931034482759
# 2022-08
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5371841901034341
# Mean of actual:        0.4
# Mean of predictions:   0.5
# Test score:            0.6666666666666665
# ETH
# 2019-12
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5933247889096591
# Mean of actual:        0.41935483870967744
# Mean of predictions:   0.6451612903225806
# Test score:            0.6060606060606061
# 2020-01
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5822911586534775
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.3225806451612903
# Test score:            0.4615384615384615
# 2020-02
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5918522963625548
# Mean of actual:        0.5862068965517241
# Mean of predictions:   0.2413793103448276
# Test score:            0.3333333333333333
# 2020-03
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.5257116217116218
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.6129032258064516
# Test score:            0.5714285714285714
# 2020-04
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5784957264957266
# Mean of actual:        0.6
# Mean of predictions:   0.4666666666666667
# Test score:            0.43750000000000006
# 2020-05
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.4966789654930072
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.8709677419354839
# Test score:            0.6666666666666667
# 2020-06
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.3885433699190505
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.7666666666666667
# Test score:            0.6111111111111112
# 2020-07
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.6254660058138318
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.22580645161290322
# Test score:            0.48
# 2020-08
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5677715805396966
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.6451612903225806
# Test score:            0.5789473684210527
# 2020-09
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.6154831545266328
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6
# Test score:            0.6857142857142857
# 2020-10
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.6814069657873149
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5483870967741935
# Test score:            0.45714285714285713
# 2020-11
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5607148956356736
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.8
# Test score:            0.5853658536585366
# 2020-12
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.48778048876544416
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.6451612903225806
# Test score:            0.6
# 2021-01
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5444835648228479
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.6129032258064516
# Test score:            0.6
# 2021-02
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5305452822398979
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.8214285714285714
# Test score:            0.6315789473684211
# 2021-03
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5356581837280368
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.7741935483870968
# Test score:            0.6829268292682927
# 2021-04
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5557208994708995
# Mean of actual:        0.6666666666666666
# Mean of predictions:   0.7
# Test score:            0.7317073170731706
# 2021-05
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.598551415526234
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.7096774193548387
# Test score:            0.5405405405405405
# 2021-06
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.5650573192239859
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.6
# Test score:            0.411764705882353
# 2021-07
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.6023374831414047
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.7419354838709677
# Test score:            0.6190476190476191
# 2021-08
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5036837606837608
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.9354838709677419
# Test score:            0.7083333333333333
# 2021-09
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.4753738761531191
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.6333333333333333
# Test score:            0.5454545454545454
# 2021-10
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.4829455954877706
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.8064516129032258
# Test score:            0.6976744186046512
# 2021-11
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5686529740427865
# Mean of actual:        0.5
# Mean of predictions:   0.7666666666666667
# Test score:            0.7368421052631579
# 2021-12
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5342278556289445
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.5161290322580645
# Test score:            0.5333333333333333
# 2022-01
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5921947810643462
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.3548387096774194
# Test score:            0.4444444444444444
# 2022-02
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5347033320946364
# Mean of actual:        0.5
# Mean of predictions:   0.4642857142857143
# Test score:            0.4444444444444445
# 2022-03
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.553855388095426
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.3870967741935484
# Test score:            0.3870967741935484
# 2022-04
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.4989290226681531
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.4666666666666667
# Test score:            0.4444444444444445
# 2022-05
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.4522301292962541
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.41935483870967744
# Test score:            0.4444444444444445
# 2022-06
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5138774722914232
# Mean of actual:        0.3333333333333333
# Mean of predictions:   0.5
# Test score:            0.24
# 2022-07
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5284257578812934
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.25806451612903225
# Test score:            0.31999999999999995
# 2022-08
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.495282095885578
# Mean of actual:        0.6
# Mean of predictions:   0.0
# Test score:            0.0
# Num train months:  9
# Model:  <class 'sklearn.linear_model._logistic.LogisticRegression'>
# BTC
# 2020-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5952321208842755
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.3870967741935484
# Test score:            0.6
# 2020-06
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5936907600700704
# Mean of actual:        0.5
# Mean of predictions:   0.5333333333333333
# Test score:            0.5161290322580646
# 2020-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5827316392060116
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6129032258064516
# Test score:            0.6842105263157895
# 2020-08
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5925415802019889
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.45161290322580644
# Test score:            0.6451612903225806
# 2020-09
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.6285161617600302
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6
# Test score:            0.6857142857142857
# 2020-10
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.6241447159454775
# Mean of actual:        0.7096774193548387
# Mean of predictions:   0.4838709677419355
# Test score:            0.6486486486486486
# 2020-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6041816325387825
# Mean of actual:        0.6
# Mean of predictions:   0.5333333333333333
# Test score:            0.5294117647058824
# 2020-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6076891895016592
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.7096774193548387
# Test score:            0.7441860465116279
# 2021-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.587115159694107
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.7419354838709677
# Test score:            0.6666666666666667
# 2021-02
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6029547357336831
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.6785714285714286
# Test score:            0.8235294117647058
# 2021-03
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.632930754112125
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.7096774193548387
# Test score:            0.761904761904762
# 2021-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6835949898476177
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.7
# Test score:            0.6285714285714286
# 2021-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6172180747662974
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.4838709677419355
# Test score:            0.689655172413793
# 2021-06
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.649928323723526
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5
# Test score:            0.689655172413793
# 2021-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6556124042154405
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6451612903225806
# Test score:            0.6153846153846154
# 2021-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6716019076165811
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5806451612903226
# Test score:            0.606060606060606
# 2021-09
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6661819998789712
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.5666666666666667
# Test score:            0.6666666666666667
# 2021-10
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6696745464904093
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.4838709677419355
# Test score:            0.7272727272727272
# 2021-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6805739004247479
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5
# Test score:            0.6206896551724138
# 2021-12
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6464348218840498
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5483870967741935
# Test score:            0.625
# 2022-01
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.653875182445004
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5806451612903226
# Test score:            0.606060606060606
# 2022-02
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6689404153358283
# Mean of actual:        0.5
# Mean of predictions:   0.5714285714285714
# Test score:            0.6666666666666666
# 2022-03
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.680220525667567
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.5483870967741935
# Test score:            0.7647058823529412
# 2022-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.655401167413303
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5666666666666667
# Test score:            0.5806451612903226
# 2022-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6536395330539471
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.45161290322580644
# Test score:            0.7096774193548386
# 2022-06
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6254438766752493
# Mean of actual:        0.4
# Mean of predictions:   0.6
# Test score:            0.6666666666666667
# 2022-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.6144550127183895
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.6451612903225806
# Test score:            0.47058823529411764
# 2022-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5562286180383038
# Mean of actual:        0.4
# Mean of predictions:   0.6
# Test score:            0.6
# ETH
# 2020-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5373672261005383
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.45161290322580644
# Test score:            0.4827586206896552
# 2020-06
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5223531248373103
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.5333333333333333
# Test score:            0.5517241379310345
# 2020-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5326219670528475
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.3548387096774194
# Test score:            0.5517241379310345
# 2020-08
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.524029196115371
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.45161290322580644
# Test score:            0.43750000000000006
# 2020-09
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5230517025884928
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6
# Test score:            0.7428571428571428
# 2020-10
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5300050605950533
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.6774193548387096
# Test score:            0.6153846153846153
# 2020-11
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5246001230808205
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6666666666666666
# Test score:            0.7027027027027027
# 2020-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5441325158709716
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.7096774193548387
# Test score:            0.6666666666666666
# 2021-01
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5391749898013665
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.5161290322580645
# Test score:            0.6486486486486486
# 2021-02
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5340101626180876
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.7857142857142857
# Test score:            0.5945945945945945
# 2021-03
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5285401397896827
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.7741935483870968
# Test score:            0.5853658536585366
# 2021-04
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4627014334074667
# Mean of actual:        0.6666666666666666
# Mean of predictions:   0.8666666666666667
# Test score:            0.6956521739130435
# 2021-05
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 0.01}
# Train score:  0.4463996554694229
# Mean of actual:        0.4838709677419355
# Mean of predictions:   1.0
# Test score:            0.6521739130434783
# 2021-06
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.43945644631290176
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.9333333333333333
# Test score:            0.6363636363636364
# 2021-07
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.46888520899927516
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.8709677419354839
# Test score:            0.7391304347826088
# 2021-08
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.43961225551360206
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.8064516129032258
# Test score:            0.7272727272727272
# 2021-09
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4792030735144744
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.6333333333333333
# Test score:            0.5454545454545454
# 2021-10
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.48744602092774336
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.7741935483870968
# Test score:            0.7142857142857143
# 2021-11
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.4940851200160381
# Mean of actual:        0.5
# Mean of predictions:   0.7333333333333333
# Test score:            0.6486486486486486
# 2021-12
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5587436826471845
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.8709677419354839
# Test score:            0.6341463414634146
# 2022-01
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5306771087272761
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.7096774193548387
# Test score:            0.5789473684210527
# 2022-02
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5264225641309458
# Mean of actual:        0.5
# Mean of predictions:   0.6785714285714286
# Test score:            0.48484848484848486
# 2022-03
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5634298548847798
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6129032258064516
# Test score:            0.5263157894736842
# 2022-04
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.4811037708664128
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.7666666666666667
# Test score:            0.6666666666666667
# 2022-05
# Best params:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1500, 'C': 100}
# Train score:  0.5652778881111241
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.5806451612903226
# Test score:            0.6250000000000001
# 2022-06
# Best params:  {'solver': 'newton-cg', 'penalty': 'l2', 'max_iter': 1500, 'C': 1.0}
# Train score:  0.5333989981159215
# Mean of actual:        0.3333333333333333
# Mean of predictions:   0.5666666666666667
# Test score:            0.37037037037037035
# 2022-07
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5084825852890198
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.41935483870967744
# Test score:            0.5333333333333333
# 2022-08
# Best params:  {'solver': 'lbfgs', 'penalty': 'l2', 'max_iter': 1500, 'C': 10}
# Train score:  0.5184827305081134
# Mean of actual:        0.6
# Mean of predictions:   0.2
# Test score:            0.5
# Num train months:  9
# Model:  <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# BTC
# 2020-05
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5311214100740524
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.3548387096774194
# Test score:            0.5517241379310345
# 2020-06
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5604129595817978
# Mean of actual:        0.5
# Mean of predictions:   0.6
# Test score:            0.606060606060606
# 2020-07
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.5898182056024538
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.6774193548387096
# Test score:            0.7500000000000001
# 2020-08
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5551522668438065
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.7096774193548387
# Test score:            0.7692307692307693
# 2020-09
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5765965850041516
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.5333333333333333
# Test score:            0.6666666666666667
# 2020-10
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.6098586000872568
# Mean of actual:        0.7096774193548387
# Mean of predictions:   0.41935483870967744
# Test score:            0.5714285714285714
# 2020-11
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5696946041001667
# Mean of actual:        0.6
# Mean of predictions:   0.7333333333333333
# Test score:            0.6
# 2020-12
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5603607439780134
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.8387096774193549
# Test score:            0.7234042553191489
# 2021-01
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5414161067745773
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.8064516129032258
# Test score:            0.5853658536585366
# 2021-02
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.4782770728465381
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.7857142857142857
# Test score:            0.6486486486486486
# 2021-03
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5242076619560906
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.7741935483870968
# Test score:            0.7272727272727272
# 2021-04
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5377544521010268
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.7666666666666667
# Test score:            0.6486486486486486
# 2021-05
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5501320618392778
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.7096774193548387
# Test score:            0.5000000000000001
# 2021-06
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5481501089396501
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5
# Test score:            0.5517241379310344
# 2021-07
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5606455655406343
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.7741935483870968
# Test score:            0.6976744186046512
# 2021-08
# Best params:  {'n_estimators': 536, 'max_depth': 4}
# Train score:  0.5318986956767275
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.6451612903225806
# Test score:            0.5714285714285715
# 2021-09
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5154372612051598
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.6333333333333333
# Test score:            0.6285714285714286
# 2021-10
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.5313534108311768
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5806451612903226
# Test score:            0.7777777777777778
# 2021-11
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5481816000311
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.6666666666666666
# Test score:            0.6470588235294117
# 2021-12
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5211215228591224
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.4838709677419355
# Test score:            0.4000000000000001
# 2022-01
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.547055980553227
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5806451612903226
# Test score:            0.5454545454545454
# 2022-02
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5181678409335733
# Mean of actual:        0.5
# Mean of predictions:   0.42857142857142855
# Test score:            0.5384615384615384
# 2022-03
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5625940989013587
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.5161290322580645
# Test score:            0.5454545454545455
# 2022-04
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5583070993199452
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.5
# Test score:            0.6206896551724138
# 2022-05
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5987382917731349
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.4838709677419355
# Test score:            0.625
# 2022-06
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5799631545517903
# Mean of actual:        0.4
# Mean of predictions:   0.6
# Test score:            0.6
# 2022-07
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5968075125915073
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.45161290322580644
# Test score:            0.42857142857142855
# 2022-08
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5857240895070416
# Mean of actual:        0.4
# Mean of predictions:   0.6
# Test score:            0.6
# ETH
# 2020-05
# Best params:  {'n_estimators': 661, 'max_depth': 4}
# Train score:  0.5247837980940142
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.5161290322580645
# Test score:            0.5161290322580646
# 2020-06
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.512896930831987
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.6
# Test score:            0.7096774193548387
# 2020-07
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5466607284258445
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.3870967741935484
# Test score:            0.5333333333333333
# 2020-08
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.5456768985985607
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5483870967741935
# Test score:            0.7428571428571428
# 2020-09
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.5577924731665458
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.5
# Test score:            0.6875
# 2020-10
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5706484974132067
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.5806451612903226
# Test score:            0.5555555555555556
# 2020-11
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5175260875910357
# Mean of actual:        0.5666666666666667
# Mean of predictions:   0.6
# Test score:            0.5714285714285715
# 2020-12
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5900492017158933
# Mean of actual:        0.6451612903225806
# Mean of predictions:   0.6774193548387096
# Test score:            0.6341463414634146
# 2021-01
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5709620769024991
# Mean of actual:        0.6774193548387096
# Mean of predictions:   0.5483870967741935
# Test score:            0.5789473684210527
# 2021-02
# Best params:  {'n_estimators': 739, 'max_depth': 7}
# Train score:  0.555539805224651
# Mean of actual:        0.5357142857142857
# Mean of predictions:   0.4642857142857143
# Test score:            0.3571428571428571
# 2021-03
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.5475021818208552
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.6129032258064516
# Test score:            0.6666666666666667
# 2021-04
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5367803534924753
# Mean of actual:        0.6666666666666666
# Mean of predictions:   0.5666666666666667
# Test score:            0.6486486486486486
# 2021-05
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.4991559505858628
# Mean of actual:        0.4838709677419355
# Mean of predictions:   0.7419354838709677
# Test score:            0.47368421052631576
# 2021-06
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5119366905169203
# Mean of actual:        0.5333333333333333
# Mean of predictions:   0.8333333333333334
# Test score:            0.6341463414634146
# 2021-07
# Best params:  {'n_estimators': 512, 'max_depth': 4}
# Train score:  0.5158382284958511
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.8709677419354839
# Test score:            0.6521739130434783
# 2021-08
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.514084288493204
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.8387096774193549
# Test score:            0.6666666666666666
# 2021-09
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.5346653192958154
# Mean of actual:        0.4666666666666667
# Mean of predictions:   0.7
# Test score:            0.5142857142857143
# 2021-10
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5308364824939227
# Mean of actual:        0.5806451612903226
# Mean of predictions:   0.8064516129032258
# Test score:            0.7441860465116279
# 2021-11
# Best params:  {'n_estimators': 773, 'max_depth': 7}
# Train score:  0.553230031328946
# Mean of actual:        0.5
# Mean of predictions:   0.7666666666666667
# Test score:            0.6315789473684211
# 2021-12
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.5291384935786184
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.5483870967741935
# Test score:            0.6451612903225806
# 2022-01
# Best params:  {'n_estimators': 545, 'max_depth': 8}
# Train score:  0.505304054213944
# Mean of actual:        0.5161290322580645
# Mean of predictions:   0.6129032258064516
# Test score:            0.5714285714285714
# 2022-02
# Best params:  {'n_estimators': 679, 'max_depth': 7}
# Train score:  0.5196240730580663
# Mean of actual:        0.5
# Mean of predictions:   0.5357142857142857
# Test score:            0.4137931034482759
# 2022-03
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5199510230896399
# Mean of actual:        0.6129032258064516
# Mean of predictions:   0.7096774193548387
# Test score:            0.5853658536585366
# 2022-04
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.4822010962719552
# Mean of actual:        0.43333333333333335
# Mean of predictions:   0.6666666666666666
# Test score:            0.5454545454545455
# 2022-05
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.5162835947237795
# Mean of actual:        0.45161290322580644
# Mean of predictions:   0.7419354838709677
# Test score:            0.5945945945945946
# 2022-06
# Best params:  {'n_estimators': 337, 'max_depth': 3}
# Train score:  0.525441906653426
# Mean of actual:        0.3333333333333333
# Mean of predictions:   0.5
# Test score:            0.32
# 2022-07
# Best params:  {'n_estimators': 616, 'max_depth': 6}
# Train score:  0.5263587744565893
# Mean of actual:        0.5483870967741935
# Mean of predictions:   0.4838709677419355
# Test score:            0.5625
# 2022-08
# Best params:  {'n_estimators': 787, 'max_depth': 5}
# Train score:  0.5485012454149343
# Mean of actual:        0.6
# Mean of predictions:   0.2
# Test score:            0.25
